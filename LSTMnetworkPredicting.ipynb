# %% [markdown]
# # Predicting the number of international airline passengers for the future
# in the previous file, we tested it out for results we already knew. Lets test it out for results we dont know.8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import numpy as np

# %% [markdown]
# Import the necessary modules

# %%
dataframe:pd.DataFrame = pd.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataframe)
plt.show()

# %% [markdown]
# Here we read the csv file containing the data as a dataframe, and we plot it.

# %% [markdown]
# We should first set a random seed

# %%
tf.random.set_seed(7)

# %% [markdown]
# Lets now change the *dataframe* from earlier to numpy integer values. Apparently this is better when working with neural networks.

# %%
dataset:np.array = dataframe.values

lengthOfPredictions = int(len(dataset) * 0.5)
nans = np.empty((lengthOfPredictions,1))
nans[:] = np.nan
dataset = np.concatenate((dataset, nans), axis=0)

dataset = dataset.astype('float32')
print(dataset)
# Out:
# [[112.]
#  [118.]
#  [132.]
#  [129.]
#  [121.]
#  [135.]
#  [148.]
#  [148.]
#  [136.]
#  [119.]
#  [104.]
#  [118.]
#  [115.]
#  [126.]
#  [141.]
#  [135.]
#  [125.]
#  [149.]
#  [170.]
#  [170.]
#  [158.]
#  [133.]
#  [114.]
#  [140.]
#  [145.]
#  [150.]
#  [178.]
#  [163.]
#  [172.]
#  [178.]
#  [199.]
#  [199.]
#  [184.]
#  [162.]
#  [146.]
#  [166.]
#  [171.]
#  [180.]
#  [193.]
#  [181.]
#  [183.]
#  [218.]
#  [230.]
#  [242.]
#  [209.]
#  [191.]
#  [172.]
#  [194.]
#  [196.]
#  [196.]
#  [236.]
#  [235.]
#  [229.]
#  [243.]
#  [264.]
#  [272.]
#  [237.]
#  [211.]
#  [180.]
#  [201.]
#  [204.]
#  [188.]
#  [235.]
#  [227.]
#  [234.]
#  [264.]
#  [302.]
#  [293.]
#  [259.]
#  [229.]
#  [203.]
#  [229.]
#  [242.]
#  [233.]
#  [267.]
#  [269.]
#  [270.]
#  [315.]
#  [364.]
#  [347.]
#  [312.]
#  [274.]
#  [237.]
#  [278.]
#  [284.]
#  [277.]
#  [317.]
#  [313.]
#  [318.]
#  [374.]
#  [413.]
#  [405.]
#  [355.]
#  [306.]
#  [271.]
#  [306.]
#  [315.]
#  [301.]
#  [356.]
#  [348.]
#  [355.]
#  [422.]
#  [465.]
#  [467.]
#  [404.]
#  [347.]
#  [305.]
#  [336.]
#  [340.]
#  [318.]
#  [362.]
#  [348.]
#  [363.]
#  [435.]
#  [491.]
#  [505.]
#  [404.]
#  [359.]
#  [310.]
#  [337.]
#  [360.]
#  [342.]
#  [406.]
#  [396.]
#  [420.]
#  [472.]
#  [548.]
#  [559.]
#  [463.]
#  [407.]
#  [362.]
#  [405.]
#  [417.]
#  [391.]
#  [419.]
#  [461.]
#  [472.]
#  [535.]
#  [622.]
#  [606.]
#  [508.]
#  [461.]
#  [390.]
#  [432.]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]
#  [ nan]]

# %% [markdown]
# We want to now scale these values down between 0 and 1 with a sigmoid or logistic function.

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)
print(dataset)
# Out:
# [[0.01544401]
#  [0.02702703]
#  [0.05405405]
#  [0.04826255]
#  [0.03281853]
#  [0.05984557]
#  [0.08494207]
#  [0.08494207]
#  [0.06177607]
#  [0.02895753]
#  [0.        ]
#  [0.02702703]
#  [0.02123553]
#  [0.04247104]
#  [0.07142857]
#  [0.05984557]
#  [0.04054055]
#  [0.08687258]
#  [0.12741312]
#  [0.12741312]
#  [0.10424709]
#  [0.05598456]
#  [0.01930502]
#  [0.06949806]
#  [0.07915059]
#  [0.08880308]
#  [0.14285713]
#  [0.11389962]
#  [0.13127413]
#  [0.14285713]
#  [0.18339768]
#  [0.18339768]
#  [0.15444016]
#  [0.11196911]
#  [0.08108109]
#  [0.1196911 ]
#  [0.12934363]
#  [0.14671814]
#  [0.17181468]
#  [0.14864865]
#  [0.15250966]
#  [0.22007722]
#  [0.24324325]
#  [0.26640925]
#  [0.2027027 ]
#  [0.16795367]
#  [0.13127413]
#  [0.17374519]
#  [0.17760617]
#  [0.17760617]
#  [0.25482625]
#  [0.25289574]
#  [0.24131274]
#  [0.26833975]
#  [0.3088803 ]
#  [0.32432434]
#  [0.25675675]
#  [0.20656371]
#  [0.14671814]
#  [0.18725869]
#  [0.19305018]
#  [0.16216215]
#  [0.25289574]
#  [0.23745173]
#  [0.25096524]
#  [0.3088803 ]
#  [0.38223937]
#  [0.36486486]
#  [0.2992278 ]
#  [0.24131274]
#  [0.1911197 ]
#  [0.24131274]
#  [0.26640925]
#  [0.24903473]
#  [0.31467178]
#  [0.3185328 ]
#  [0.32046333]
#  [0.4073359 ]
#  [0.5019305 ]
#  [0.46911195]
#  [0.40154442]
#  [0.32818535]
#  [0.25675675]
#  [0.3359073 ]
#  [0.34749034]
#  [0.33397684]
#  [0.41119692]
#  [0.4034749 ]
#  [0.4131274 ]
#  [0.52123547]
#  [0.5965251 ]
#  [0.58108103]
#  [0.484556  ]
#  [0.3899614 ]
#  [0.3223938 ]
#  [0.3899614 ]
#  [0.4073359 ]
#  [0.3803089 ]
#  [0.48648646]
#  [0.47104248]
#  [0.484556  ]
#  [0.6138996 ]
#  [0.6969112 ]
#  [0.70077217]
#  [0.57915056]
#  [0.46911195]
#  [0.38803086]
#  [0.44787642]
#  [0.45559844]
#  [0.4131274 ]
#  [0.4980695 ]
#  [0.47104248]
#  [0.49999997]
#  [0.6389961 ]
#  [0.7471043 ]
#  [0.7741313 ]
#  [0.57915056]
#  [0.492278  ]
#  [0.3976834 ]
#  [0.44980696]
#  [0.49420848]
#  [0.45945945]
#  [0.5830116 ]
#  [0.5637065 ]
#  [0.61003864]
#  [0.71042466]
#  [0.8571429 ]
#  [0.8783784 ]
#  [0.69305015]
#  [0.5849421 ]
#  [0.4980695 ]
#  [0.58108103]
#  [0.6042471 ]
#  [0.554054  ]
#  [0.60810804]
#  [0.6891892 ]
#  [0.71042466]
#  [0.8320464 ]
#  [1.        ]
#  [0.96911204]
#  [0.7799227 ]
#  [0.6891892 ]
#  [0.55212355]
#  [0.6332046 ]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]]

# %% [markdown]
# The airline problem is time based, meaning that the sequence of values is significant. Therefore, lets use the first 2 thirds of the data to train the model, and lets predict the last third, and compare it with the actual values.

# %%
trainingSize = int(len(dataset)) - lengthOfPredictions
testingSize = lengthOfPredictions
trainingValues = dataset[:trainingSize]
testingValues = dataset[trainingSize:]
print(f"Training size: {len(trainingValues)}\nTesting size:{len(testingValues)}")
# Out:
# Training size: 144
# Testing size:72

# %% [markdown]
# Now we can define a function to create a new dataset, as described above.
#
# The function takes two arguments: the dataset, which is a NumPy array that we want to convert into a dataset, and the look_back, which is the number of previous time steps to use as input variables to predict the next time period — in this case defaulted to 1.
#
# This default will create a dataset where X is the number of passengers at a given time (t) and Y is the number of passengers at the next time (t + 1).

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# Lets use this function

# %%
# reshape into X=t and Y=t+1
look_back = 5
trainX, trainY = create_dataset(trainingValues, look_back)
testX, testY = create_dataset(testingValues, look_back)
# print(trainX)
print(trainY)
# Out:
# [0.05984557 0.08494207 0.08494207 0.06177607 0.02895753 0.
#  0.02702703 0.02123553 0.04247104 0.07142857 0.05984557 0.04054055
#  0.08687258 0.12741312 0.12741312 0.10424709 0.05598456 0.01930502
#  0.06949806 0.07915059 0.08880308 0.14285713 0.11389962 0.13127413
#  0.14285713 0.18339768 0.18339768 0.15444016 0.11196911 0.08108109
#  0.1196911  0.12934363 0.14671814 0.17181468 0.14864865 0.15250966
#  0.22007722 0.24324325 0.26640925 0.2027027  0.16795367 0.13127413
#  0.17374519 0.17760617 0.17760617 0.25482625 0.25289574 0.24131274
#  0.26833975 0.3088803  0.32432434 0.25675675 0.20656371 0.14671814
#  0.18725869 0.19305018 0.16216215 0.25289574 0.23745173 0.25096524
#  0.3088803  0.38223937 0.36486486 0.2992278  0.24131274 0.1911197
#  0.24131274 0.26640925 0.24903473 0.31467178 0.3185328  0.32046333
#  0.4073359  0.5019305  0.46911195 0.40154442 0.32818535 0.25675675
#  0.3359073  0.34749034 0.33397684 0.41119692 0.4034749  0.4131274
#  0.52123547 0.5965251  0.58108103 0.484556   0.3899614  0.3223938
#  0.3899614  0.4073359  0.3803089  0.48648646 0.47104248 0.484556
#  0.6138996  0.6969112  0.70077217 0.57915056 0.46911195 0.38803086
#  0.44787642 0.45559844 0.4131274  0.4980695  0.47104248 0.49999997
#  0.6389961  0.7471043  0.7741313  0.57915056 0.492278   0.3976834
#  0.44980696 0.49420848 0.45945945 0.5830116  0.5637065  0.61003864
#  0.71042466 0.8571429  0.8783784  0.69305015 0.5849421  0.4980695
#  0.58108103 0.6042471  0.554054   0.60810804 0.6891892  0.71042466
#  0.8320464  1.         0.96911204 0.7799227  0.6891892  0.55212355]

# %% [markdown]
# The LSTM network expects the input data (X) to be provided with a specific array structure in the form of: [samples, time steps, features].
#
# Currently, our data is in the form: [samples, features] and we are framing the problem as one time step for each sample. We can transform the prepared train and test input data into the expected structure using numpy.reshape() as follows:

# %%
# reshape input to be [samples, time steps, features]
# print(testX)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
#  [[0.3976834  0.44980696 0.49420848 0.45945945 0.5830116 ]]
#
#  [[0.44980696 0.49420848 0.45945945 0.5830116  0.5637065 ]]
#
#  [[0.49420848 0.45945945 0.5830116  0.5637065  0.61003864]]
#
#  [[0.45945945 0.5830116  0.5637065  0.61003864 0.71042466]]
#
#  [[0.5830116  0.5637065  0.61003864 0.71042466 0.8571429 ]]
#
#  [[0.5637065  0.61003864 0.71042466 0.8571429  0.8783784 ]]
#
#  [[0.61003864 0.71042466 0.8571429  0.8783784  0.69305015]]
#
#  [[0.71042466 0.8571429  0.8783784  0.69305015 0.5849421 ]]
#
#  [[0.8571429  0.8783784  0.69305015 0.5849421  0.4980695 ]]
#
#  [[0.8783784  0.69305015 0.5849421  0.4980695  0.58108103]]
#
#  [[0.69305015 0.5849421  0.4980695  0.58108103 0.6042471 ]]
#
#  [[0.5849421  0.4980695  0.58108103 0.6042471  0.554054  ]]
#
#  [[0.4980695  0.58108103 0.6042471  0.554054   0.60810804]]
#
#  [[0.58108103 0.6042471  0.554054   0.60810804 0.6891892 ]]
#
#  [[0.6042471  0.554054   0.60810804 0.6891892  0.71042466]]
#
#  [[0.554054   0.60810804 0.6891892  0.71042466 0.8320464 ]]
#
#  [[0.60810804 0.6891892  0.71042466 0.8320464  1.        ]]
#
#  [[0.6891892  0.71042466 0.8320464  1.         0.96911204]]
#
#  [[0.71042466 0.8320464  1.         0.96911204 0.7799227 ]]
#
#  [[0.8320464  1.         0.96911204 0.7799227  0.6891892 ]]]

# %% [markdown]
# We are now ready to design and fit our LSTM network for this problem.
#
# The network has a visible layer with 1 input, a hidden layer with 4 LSTM blocks or neurons, and an output layer that makes a single value prediction. The default sigmoid activation function is used for the LSTM blocks. The network is trained for 100 epochs and a batch size of 1 is used.

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 138/138 - 1s - loss: 0.1194 - 1s/epoch - 9ms/step
# Epoch 2/100
# 138/138 - 0s - loss: 0.0385 - 124ms/epoch - 896us/step
# Epoch 3/100
# 138/138 - 0s - loss: 0.0217 - 122ms/epoch - 884us/step
# Epoch 4/100
# 138/138 - 0s - loss: 0.0181 - 139ms/epoch - 1ms/step
# Epoch 5/100
# 138/138 - 0s - loss: 0.0158 - 124ms/epoch - 896us/step
# Epoch 6/100
# 138/138 - 0s - loss: 0.0141 - 118ms/epoch - 853us/step
# Epoch 7/100
# 138/138 - 0s - loss: 0.0129 - 127ms/epoch - 918us/step
# Epoch 8/100
# 138/138 - 0s - loss: 0.0118 - 123ms/epoch - 889us/step
# Epoch 9/100
# 138/138 - 0s - loss: 0.0113 - 120ms/epoch - 868us/step
# Epoch 10/100
# 138/138 - 0s - loss: 0.0108 - 123ms/epoch - 889us/step
# Epoch 11/100
# 138/138 - 0s - loss: 0.0104 - 127ms/epoch - 918us/step
# Epoch 12/100
# 138/138 - 0s - loss: 0.0100 - 122ms/epoch - 887us/step
# Epoch 13/100
# 138/138 - 0s - loss: 0.0097 - 117ms/epoch - 845us/step
# Epoch 14/100
# 138/138 - 0s - loss: 0.0095 - 118ms/epoch - 856us/step
# Epoch 15/100
# 138/138 - 0s - loss: 0.0093 - 132ms/epoch - 954us/step
# Epoch 16/100
# 138/138 - 0s - loss: 0.0091 - 119ms/epoch - 866us/step
# Epoch 17/100
# 138/138 - 0s - loss: 0.0086 - 121ms/epoch - 878us/step
# Epoch 18/100
# 138/138 - 0s - loss: 0.0086 - 125ms/epoch - 903us/step
# Epoch 19/100
# 138/138 - 0s - loss: 0.0082 - 123ms/epoch - 894us/step
# Epoch 20/100
# 138/138 - 0s - loss: 0.0079 - 120ms/epoch - 872us/step
# Epoch 21/100
# 138/138 - 0s - loss: 0.0078 - 123ms/epoch - 891us/step
# Epoch 22/100
# 138/138 - 0s - loss: 0.0076 - 120ms/epoch - 871us/step
# Epoch 23/100
# 138/138 - 0s - loss: 0.0073 - 114ms/epoch - 826us/step
# Epoch 24/100
# 138/138 - 0s - loss: 0.0072 - 118ms/epoch - 855us/step
# Epoch 25/100
# 138/138 - 0s - loss: 0.0069 - 125ms/epoch - 905us/step
# Epoch 26/100
# 138/138 - 0s - loss: 0.0067 - 117ms/epoch - 846us/step
# Epoch 27/100
# 138/138 - 0s - loss: 0.0066 - 120ms/epoch - 867us/step
# Epoch 28/100
# 138/138 - 0s - loss: 0.0062 - 132ms/epoch - 954us/step
# Epoch 29/100
# 138/138 - 0s - loss: 0.0062 - 132ms/epoch - 953us/step
# Epoch 30/100
# 138/138 - 0s - loss: 0.0062 - 115ms/epoch - 830us/step
# Epoch 31/100
# 138/138 - 0s - loss: 0.0059 - 122ms/epoch - 883us/step
# Epoch 32/100
# 138/138 - 0s - loss: 0.0058 - 120ms/epoch - 867us/step
# Epoch 33/100
# 138/138 - 0s - loss: 0.0056 - 142ms/epoch - 1ms/step
# Epoch 34/100
# 138/138 - 0s - loss: 0.0055 - 126ms/epoch - 910us/step
# Epoch 35/100
# 138/138 - 0s - loss: 0.0053 - 120ms/epoch - 867us/step
# Epoch 36/100
# 138/138 - 0s - loss: 0.0053 - 117ms/epoch - 849us/step
# Epoch 37/100
# 138/138 - 0s - loss: 0.0052 - 115ms/epoch - 831us/step
# Epoch 38/100
# 138/138 - 0s - loss: 0.0051 - 122ms/epoch - 881us/step
# Epoch 39/100
# 138/138 - 0s - loss: 0.0052 - 116ms/epoch - 838us/step
# Epoch 40/100
# 138/138 - 0s - loss: 0.0050 - 116ms/epoch - 843us/step
# Epoch 41/100
# 138/138 - 0s - loss: 0.0050 - 118ms/epoch - 857us/step
# Epoch 42/100
# 138/138 - 0s - loss: 0.0049 - 119ms/epoch - 864us/step
# Epoch 43/100
# 138/138 - 0s - loss: 0.0047 - 117ms/epoch - 846us/step
# Epoch 44/100
# 138/138 - 0s - loss: 0.0048 - 119ms/epoch - 865us/step
# Epoch 45/100
# 138/138 - 0s - loss: 0.0047 - 118ms/epoch - 853us/step
# Epoch 46/100
# 138/138 - 0s - loss: 0.0046 - 126ms/epoch - 913us/step
# Epoch 47/100
# 138/138 - 0s - loss: 0.0046 - 122ms/epoch - 883us/step
# Epoch 48/100
# 138/138 - 0s - loss: 0.0046 - 117ms/epoch - 848us/step
# Epoch 49/100
# 138/138 - 0s - loss: 0.0045 - 118ms/epoch - 853us/step
# Epoch 50/100
# 138/138 - 0s - loss: 0.0047 - 121ms/epoch - 875us/step
# Epoch 51/100
# 138/138 - 0s - loss: 0.0044 - 120ms/epoch - 867us/step
# Epoch 52/100
# 138/138 - 0s - loss: 0.0045 - 120ms/epoch - 871us/step
# Epoch 53/100
# 138/138 - 0s - loss: 0.0044 - 116ms/epoch - 841us/step
# Epoch 54/100
# 138/138 - 0s - loss: 0.0043 - 128ms/epoch - 925us/step
# Epoch 55/100
# 138/138 - 0s - loss: 0.0043 - 116ms/epoch - 843us/step
# Epoch 56/100
# 138/138 - 0s - loss: 0.0046 - 115ms/epoch - 837us/step
# Epoch 57/100
# 138/138 - 0s - loss: 0.0042 - 118ms/epoch - 857us/step
# Epoch 58/100
# 138/138 - 0s - loss: 0.0044 - 118ms/epoch - 854us/step
# Epoch 59/100
# 138/138 - 0s - loss: 0.0041 - 119ms/epoch - 864us/step
# Epoch 60/100
# 138/138 - 0s - loss: 0.0043 - 116ms/epoch - 838us/step
# Epoch 61/100
# 138/138 - 0s - loss: 0.0041 - 120ms/epoch - 867us/step
# Epoch 62/100
# 138/138 - 0s - loss: 0.0042 - 118ms/epoch - 854us/step
# Epoch 63/100
# 138/138 - 0s - loss: 0.0039 - 121ms/epoch - 874us/step
# Epoch 64/100
# 138/138 - 0s - loss: 0.0041 - 115ms/epoch - 833us/step
# Epoch 65/100
# 138/138 - 0s - loss: 0.0041 - 116ms/epoch - 844us/step
# Epoch 66/100
# 138/138 - 0s - loss: 0.0042 - 113ms/epoch - 821us/step
# Epoch 67/100
# 138/138 - 0s - loss: 0.0041 - 120ms/epoch - 870us/step
# Epoch 68/100
# 138/138 - 0s - loss: 0.0041 - 120ms/epoch - 867us/step
# Epoch 69/100
# 138/138 - 0s - loss: 0.0041 - 119ms/epoch - 860us/step
# Epoch 70/100
# 138/138 - 0s - loss: 0.0041 - 117ms/epoch - 847us/step
# Epoch 71/100
# 138/138 - 0s - loss: 0.0040 - 118ms/epoch - 853us/step
# Epoch 72/100
# 138/138 - 0s - loss: 0.0045 - 117ms/epoch - 846us/step
# Epoch 73/100
# 138/138 - 0s - loss: 0.0041 - 116ms/epoch - 838us/step
# Epoch 74/100
# 138/138 - 0s - loss: 0.0040 - 117ms/epoch - 846us/step
# Epoch 75/100
# 138/138 - 0s - loss: 0.0040 - 135ms/epoch - 976us/step
# Epoch 76/100
# 138/138 - 0s - loss: 0.0040 - 125ms/epoch - 903us/step
# Epoch 77/100
# 138/138 - 0s - loss: 0.0040 - 118ms/epoch - 856us/step
# Epoch 78/100
# 138/138 - 0s - loss: 0.0039 - 120ms/epoch - 867us/step
# Epoch 79/100
# 138/138 - 0s - loss: 0.0039 - 126ms/epoch - 910us/step
# Epoch 80/100
# 138/138 - 0s - loss: 0.0039 - 118ms/epoch - 853us/step
# Epoch 81/100
# 138/138 - 0s - loss: 0.0039 - 112ms/epoch - 809us/step
# Epoch 82/100
# 138/138 - 0s - loss: 0.0039 - 117ms/epoch - 848us/step
# Epoch 83/100
# 138/138 - 0s - loss: 0.0039 - 119ms/epoch - 860us/step
# Epoch 84/100
# 138/138 - 0s - loss: 0.0039 - 160ms/epoch - 1ms/step
# Epoch 85/100
# 138/138 - 0s - loss: 0.0038 - 116ms/epoch - 838us/step
# Epoch 86/100
# 138/138 - 0s - loss: 0.0039 - 116ms/epoch - 843us/step
# Epoch 87/100
# 138/138 - 0s - loss: 0.0039 - 119ms/epoch - 860us/step
# Epoch 88/100
# 138/138 - 0s - loss: 0.0037 - 114ms/epoch - 824us/step
# Epoch 89/100
# 138/138 - 0s - loss: 0.0038 - 114ms/epoch - 827us/step
# Epoch 90/100
# 138/138 - 0s - loss: 0.0039 - 114ms/epoch - 824us/step
# Epoch 91/100
# 138/138 - 0s - loss: 0.0038 - 122ms/epoch - 885us/step
# Epoch 92/100
# 138/138 - 0s - loss: 0.0039 - 119ms/epoch - 860us/step
# Epoch 93/100
# 138/138 - 0s - loss: 0.0039 - 117ms/epoch - 845us/step
# Epoch 94/100
# 138/138 - 0s - loss: 0.0037 - 117ms/epoch - 851us/step
# Epoch 95/100
# 138/138 - 0s - loss: 0.0040 - 118ms/epoch - 851us/step
# Epoch 96/100
# 138/138 - 0s - loss: 0.0038 - 117ms/epoch - 846us/step
# Epoch 97/100
# 138/138 - 0s - loss: 0.0039 - 119ms/epoch - 866us/step
# Epoch 98/100
# 138/138 - 0s - loss: 0.0038 - 122ms/epoch - 882us/step
# Epoch 99/100
# 138/138 - 0s - loss: 0.0039 - 122ms/epoch - 882us/step
# Epoch 100/100
# 138/138 - 0s - loss: 0.0037 - 115ms/epoch - 831us/step

# %% [markdown]
# Once the model is fit, we can estimate the performance of the model on the train and test datasets. This will give us a point of comparison for new models.
#
# Note that we invert the predictions before calculating error scores to ensure that performance is reported in the same units as the original data (thousands of passengers per month).

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
print(trainPredict)
# Out:
# [[0.03201716]
#  [0.05614888]
#  [0.08297341]
#  [0.07762778]
#  [0.05516303]
#  [0.03576395]
#  [0.02075831]
#  [0.04337257]
#  [0.03786165]
#  [0.04275621]
#  [0.06199241]
#  [0.0556661 ]
#  [0.03748526]
#  [0.07981409]
#  [0.12160159]
#  [0.11175092]
#  [0.0866918 ]
#  [0.0582311 ]
#  [0.03847181]
#  [0.083082  ]
#  [0.09031626]
#  [0.07968466]
#  [0.11957364]
#  [0.1054794 ]
#  [0.11340202]
#  [0.13526271]
#  [0.17568108]
#  [0.1710398 ]
#  [0.1417568 ]
#  [0.10958533]
#  [0.09389942]
#  [0.13153493]
#  [0.13794571]
#  [0.13608968]
#  [0.15479362]
#  [0.13986501]
#  [0.1414065 ]
#  [0.21353988]
#  [0.23884833]
#  [0.24334523]
#  [0.18678983]
#  [0.1611406 ]
#  [0.14663649]
#  [0.18893893]
#  [0.18781255]
#  [0.1694346 ]
#  [0.2387454 ]
#  [0.24757469]
#  [0.21981601]
#  [0.25519335]
#  [0.3118116 ]
#  [0.3196918 ]
#  [0.24403806]
#  [0.19856918]
#  [0.16497715]
#  [0.20752716]
#  [0.21304992]
#  [0.1611488 ]
#  [0.23749484]
#  [0.24035794]
#  [0.22982594]
#  [0.2964091 ]
#  [0.382715  ]
#  [0.35053775]
#  [0.27327138]
#  [0.23618588]
#  [0.21096663]
#  [0.2632102 ]
#  [0.28704262]
#  [0.24278468]
#  [0.2983774 ]
#  [0.32064974]
#  [0.30656898]
#  [0.40024224]
#  [0.5110299 ]
#  [0.45269418]
#  [0.3632717 ]
#  [0.31961572]
#  [0.27271217]
#  [0.36011648]
#  [0.3814601 ]
#  [0.32471028]
#  [0.4002833 ]
#  [0.41193822]
#  [0.3962506 ]
#  [0.5204425 ]
#  [0.60598505]
#  [0.5538707 ]
#  [0.44172522]
#  [0.3661479 ]
#  [0.33288342]
#  [0.4180756 ]
#  [0.44289523]
#  [0.37321672]
#  [0.47722274]
#  [0.48492745]
#  [0.45875132]
#  [0.61064   ]
#  [0.7001401 ]
#  [0.6576947 ]
#  [0.5194907 ]
#  [0.41910043]
#  [0.38596934]
#  [0.46943   ]
#  [0.49151143]
#  [0.40564576]
#  [0.48914403]
#  [0.48707387]
#  [0.47904938]
#  [0.64121056]
#  [0.74469924]
#  [0.7236454 ]
#  [0.50477535]
#  [0.41818404]
#  [0.40814185]
#  [0.46446702]
#  [0.5309917 ]
#  [0.45733064]
#  [0.5656064 ]
#  [0.5746559 ]
#  [0.5715251 ]
#  [0.69723964]
#  [0.82465035]
#  [0.8150197 ]
#  [0.5870489 ]
#  [0.48347312]
#  [0.47812003]
#  [0.57849044]
#  [0.62823856]
#  [0.5272242 ]
#  [0.5778083 ]
#  [0.6892312 ]
#  [0.68521845]
#  [0.7752839 ]
#  [0.92986286]
#  [0.8646984 ]
#  [0.62536234]
#  [0.56303453]]

# %%
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
# trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
# print('Train Score: %.2f RMSE' % (trainScore))
# testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
# print('Test Score: %.2f RMSE' % (testScore))


allVals = np.concatenate((trainPredict, testPredict), axis=0)
print(len(allVals))
print(len(testPredict))
print(len(trainPredict))
# Out:
# 204
# 66
# 138

# %% [markdown]
# Finally, we can generate predictions using the model for both the train and test dataset to get a visual indication of the skill of the model.
#
# Because of how the dataset was prepared, we must shift the predictions so that they align on the x-axis with the original dataset. Once prepared, the data is plotted, showing the original dataset in blue, the predictions for the training dataset in orange, and the predictions on the unseen test dataset in green.

# %%
# shift train predictions for plotting
print(dataset.shape)
trainPredictPlot = np.empty(shape=(19000, 1))
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
print(testPredict.shape)
print(testPredict)
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset), label="base")
plt.plot(trainPredictPlot, label="trainpredict")
plt.plot(testPredictPlot, label="testPredict")
# plt.plot(allVals, label="allVals")
plt.legend()
plt.show()
# Out:
# (216, 1)
# (66, 1)
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]

# %%
print(testPredictPlot)
# Out:
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
